# %%
import random
import requests
from datetime import datetime, timedelta
from concurrent.futures import ProcessPoolExecutor
import json

# %%
api_key = '337586e7326dcb828d7a386379093040'

# %%
# Function to get current weather
def get_weather(city):
    url = f"http://api.openweathermap.org/data/2.5/weather?q={city}&appid={api_key}&units=metric"
    response = requests.get(url)
    return response.json() if response.status_code == 200 else None

# Function to get weather forecast
def get_forecast(city):
    url = f"http://api.openweathermap.org/data/2.5/forecast?q={city}&appid={api_key}&units=metric"
    response = requests.get(url)
    return response.json() if response.status_code == 200 else None

# Generate random future date within the next 5 days
def generate_random_future_date():
    days = random.randint(1, 5)
    future_date = datetime.now() + timedelta(days=days)
    return future_date.strftime('%Y-%m-%d')

# Function to create a user prompt and intent extraction
def create_user_prompt_and_intent(dummy):
    cities = [
        "Kolkata", "New York", "London", "Tokyo", "Sydney", "Paris", "Berlin", "Toronto",
        "Mumbai", "Shanghai", "Los Angeles", "Chicago", "Houston", "Phoenix", "Philadelphia",
        "San Antonio", "San Diego", "Dallas", "San Jose", "Austin", "Beijing", "Moscow",
        "Bangkok", "Cairo", "Istanbul", "Buenos Aires", "Rio de Janeiro", "Lagos", "Lima",
        "Jakarta", "Karachi", "Santiago", "Seoul", "Mexico City", "São Paulo", "Dubai",
        "Singapore", "Hong Kong", "Kuala Lumpur", "Tehran", "Baghdad", "Hanoi", "Riyadh",
        "Cape Town", "Nairobi", "Casablanca", "Accra", "Addis Ababa", "Ho Chi Minh City",
        "Manila", "Dhaka", "Abu Dhabi", "Ankara", "Brisbane", "Barcelona", "Madrid",
        "Rome", "Vienna", "Zurich", "Copenhagen", "Oslo", "Stockholm", "Helsinki", "Athens",
        "Budapest", "Warsaw", "Prague", "Brussels", "Amsterdam", "Dublin", "Edinburgh",
        "Glasgow", "Lisbon", "Munich", "Frankfurt", "Hamburg", "Stuttgart", "Lyon", "Marseille",
        "Nice", "Bordeaux", "Toulouse", "Venice", "Florence", "Naples", "Milan", "Turin",
        "Bologna", "Palermo", "Athens", "Thessaloniki", "Osaka", "Nagoya", "Kyoto", "Fukuoka",
        "Sapporo", "Sendai", "Yokohama", "Kobe", "Hiroshima"
    ]
    info_requests = ["current_weather", "forecast_weather"]
    dates = ["today", "tomorrow"] + [generate_random_future_date() for _ in range(8)]

    city = random.choice(cities)
    info_request = random.choice(info_requests)
    date = random.choice(dates) if info_request == "forecast_weather" else "today"
    user_prompt = f"What is the {info_request.replace('_', ' ')} in {city} {date}?"

    intent_extraction = {
        "intent": info_request,
        "entities": {
            "city": city,
            "date": date
        }
    }

    return {
        "user_input": user_prompt,
        "intent_extraction": intent_extraction
    }

# Generate the intent identification dataset
def generate_intent_dataset(num_samples=500):
    with ProcessPoolExecutor() as executor:
        results = list(executor.map(create_user_prompt_and_intent, range(num_samples)))
    return results

# %%
# Generate the intent identification dataset
intent_dataset = generate_intent_dataset()

# %%
intent_dataset

# %%
with open('data/intent_dataset.json', 'w') as f:
    json.dump(intent_dataset, f, indent=4)

# %%
len(intent_dataset)
# Out:
# 500

# %%
# Function to create a response dataset entry based on the intent
def create_response_dataset_entry(intent_entry):
    city = intent_entry["intent_extraction"]["entities"]["city"]
    info_request = intent_entry["intent_extraction"]["intent"]
    date = intent_entry["intent_extraction"]["entities"]["date"]
    user_prompt = intent_entry["user_input"]

    if info_request == "current_weather":
        api_response = get_weather(city)
        if api_response:
            weather = api_response['weather'][0]['description']
            temp = api_response['main']['temp']
            wind_speed = api_response['wind']['speed']
            humidity = api_response['main']['humidity']

            generated_response = (
                f"The weather in {city} is currently {weather} with a temperature of {temp}°C, "
                f"wind speed of {wind_speed} meters per second, and humidity of {humidity}%."
            )

            return {
                "user_input": user_prompt,
                "api_response": {
                    "location": f"{city}, {api_response['sys']['country']}",
                    "temperature": temp,
                    "description": weather,
                    "wind_speed": wind_speed,
                    "humidity": humidity
                },
                "assistant_response": generated_response
            }

    elif info_request == "forecast_weather":
        api_response = get_forecast(city)
        if api_response:
            forecast_list = api_response['list']
            filtered_forecasts = [forecast for forecast in forecast_list if date in forecast['dt_txt']]
            if filtered_forecasts:
                selected_forecast = filtered_forecasts[0]
                forecast_temp = selected_forecast['main']['temp']
                forecast_weather = selected_forecast['weather'][0]['description']
                wind_speed = selected_forecast['wind']['speed']
                humidity = selected_forecast['main']['humidity']

                generated_response = (
                    f"The forecast for {city} on {date} is {forecast_weather} with a temperature of {forecast_temp}°C, "
                    f"wind speed of {wind_speed} meters per second, and humidity of {humidity}%."
                )

                return {
                    "user_input": user_prompt,
                    "api_response": {
                        "date": date,
                        "temperature": forecast_temp,
                        "description": forecast_weather,
                        "wind_speed": wind_speed,
                        "humidity": humidity
                    },
                    "assistant_response": generated_response
                }

# Generate the response generation dataset
def generate_response_dataset(intent_dataset):
    with ProcessPoolExecutor() as executor:
        results = list(executor.map(create_response_dataset_entry, intent_dataset))
    return [result for result in results if result is not None]

# %%
response_dataset = generate_response_dataset(intent_dataset)

# %%
with open('data/response_dataset.json', 'w') as f:
    json.dump(response_dataset, f, indent=4)

# %%
len(response_dataset)
# Out:
# 416

# %%
response_dataset
# Out:
# [{'user_input': 'What is the forecast weather in Brisbane 2024-06-15?',
#   'api_response': {'date': '2024-06-15',
#    'temperature': 16.91,
#    'description': 'clear sky',
#    'wind_speed': 2.54,
#    'humidity': 39},
#   'assistant_response': 'The forecast for Brisbane on 2024-06-15 is clear sky with a temperature of 16.91°C, wind speed of 2.54 meters per second, and humidity of 39%.'},
#  {'user_input': 'What is the current weather in Prague today?',
#   'api_response': {'location': 'Prague, CZ',
#    'temperature': 23.59,
#    'description': 'clear sky',
#    'wind_speed': 4.12,
#    'humidity': 41},
#   'assistant_response': 'The weather in Prague is currently clear sky with a temperature of 23.59°C, wind speed of 4.12 meters per second, and humidity of 41%.'},
#  {'user_input': 'What is the current weather in Shanghai today?',
#   'api_response': {'location': 'Shanghai, CN',
#    'temperature': 21.76,
#    'description': 'broken clouds',
#    'wind_speed': 5,
#    'humidity': 91},
#   'assistant_response': 'The weather in Shanghai is currently broken clouds with a temperature of 21.76°C, wind speed of 5 meters per second, and humidity of 91%.'},
#  {'user_input': 'What is the forecast weather in Stockholm 2024-06-14?',
#   'api_response': {'date': '2024-06-14',
#    'temperature': 8.97,
#    'description': 'scattered clouds',
#    'wind_speed': 2.06,
#    'humidity': 93},
#   'assistant_response': 'The forecast for Stockholm on 2024-06-14 is scattered clouds with a temperature of 8.97°C, wind speed of 2.06 meters per second, and humidity of 93%.'},
#  {'user_input': 'What is the forecast weather in Brisbane 2024-06-15?',
#   'api_response': {'date': '2024-06-15',
#    'temperature': 15.65,
#    'description': 'clear sky',
#    'wind_speed': 2.47,
#    'humidity': 44},
#   'assistant_response': 'The forecast for Brisbane on 2024-06-15 is clear sky with a temperature of 15.65°C, wind speed of 2.47 meters per second, and humidity of 44%.'},
#  {'user_input': 'What is the forecast weather in Copenhagen 2024-06-11?',
#   'api_response': {'date': '2024-06-11',
#    'temperature': 11.6,
#    'description': 'light rain',
#    'wind_speed': 3.2,
#    'humidity': 85},
#   'assistant_response': 'The forecast for Copenhagen on 2024-06-11 is light rain with a temperature of 11.6°C, wind speed of 3.2 meters per second, and humidity of 85%.'},
#  {'user_input': 'What is the forecast weather in Beijing 2024-06-12?',
#   'api_response': {'date': '2024-06-12',
#    'temperature': 27.93,
#    'description': 'scattered clouds',
#    'wind_speed': 2.31,
#    'humidity': 41},
#   'assistant_response': 'The forecast for Beijing on 2024-06-12 is scattered clouds with a temperature of 27.93°C, wind speed of 2.31 meters per second, and humidity of 41%.'},
#  {'user_input': 'What is the forecast weather in Shanghai 2024-06-12?',
#   'api_response': {'date': '2024-06-12',
#    'temperature': 22.95,
#    'description': 'overcast clouds',
#    'wind_speed': 2.3,
#    'humidity': 85},
#   'assistant_response': 'The forecast for Shanghai on 2024-06-12 is overcast clouds with a temperature of 22.95°C, wind speed of 2.3 meters per second, and humidity of 85%.'},
#  {'user_input': 'What is the current weather in Fukuoka today?',
#   'api_response': {'location': 'Fukuoka, JP',
#    'temperature': 21.84,
#    'description': 'overcast clouds',
#    'wind_speed': 1.03,
#    'humidity': 83},
#   'assistant_response': 'The weather in Fukuoka is currently overcast clouds with a temperature of 21.84°C, wind speed of 1.03 meters per second, and humidity of 83%.'},
#  {'user_input': 'What is the current weather in Tehran today?',
#   'api_response': {'location': 'Tehran, IR',
#    'temperature': 31.11,
#    'description': 'broken clouds',
#    'wind_speed': 4.02,
#    'humidity': 11},
#   'assistant_response': 'The weather in Tehran is currently broken clouds with a temperature of 31.11°C, wind speed of 4.02 meters per second, and humidity of 11%.'},
#  {'user_input': 'What is the current weather in Dublin today?',
#   'api_response': {'location': 'Dublin, US',
#    'temperature': 14.29,
#    'description': 'few clouds',
#    'wind_speed': 2.06,
#    'humidity': 82},
#   'assistant_response': 'The weather in Dublin is currently few clouds with a temperature of 14.29°C, wind speed of 2.06 meters per second, and humidity of 82%.'},
#  {'user_input': 'What is the current weather in Bologna today?',
#   'api_response': {'location': 'Bologna, IT',
#    'temperature': 28.7,
#    'description': 'light rain',
#    'wind_speed': 6.17,
#    'humidity': 48},
#   'assistant_response': 'The weather in Bologna is currently light rain with a temperature of 28.7°C, wind speed of 6.17 meters per second, and humidity of 48%.'},
#  {'user_input': 'What is the current weather in Shanghai today?',
#   'api_response': {'location': 'Shanghai, CN',
#    'temperature': 21.76,
#    'description': 'broken clouds',
#    'wind_speed': 5,
#    'humidity': 91},
#   'assistant_response': 'The weather in Shanghai is currently broken clouds with a temperature of 21.76°C, wind speed of 5 meters per second, and humidity of 91%.'},
#  {'user_input': 'What is the current weather in Dallas today?',
#   'api_response': {'location': 'Dallas, US',
#    'temperature': 26.74,
#    'description': 'overcast clouds',
#    'wind_speed': 1.54,
#    'humidity': 80},
#   'assistant_response': 'The weather in Dallas is currently overcast clouds with a temperature of 26.74°C, wind speed of 1.54 meters per second, and humidity of 80%.'},
#  {'user_input': 'What is the forecast weather in Accra 2024-06-11?',
#   'api_response': {'date': '2024-06-11',
#    'temperature': 26.35,
#    'description': 'light rain',
#    'wind_speed': 6.14,
#    'humidity': 84},
#   'assistant_response': 'The forecast for Accra on 2024-06-11 is light rain with a temperature of 26.35°C, wind speed of 6.14 meters per second, and humidity of 84%.'},
#  {'user_input': 'What is the forecast weather in Sapporo 2024-06-15?',
#   'api_response': {'date': '2024-06-15',
#    'temperature': 19.44,
#    'description': 'scattered clouds',
#    'wind_speed': 5.32,
#    'humidity': 66},
#   'assistant_response': 'The forecast for Sapporo on 2024-06-15 is scattered clouds with a temperature of 19.44°C, wind speed of 5.32 meters per second, and humidity of 66%.'},
#  {'user_input': 'What is the forecast weather in Palermo 2024-06-14?',
#   'api_response': {'date': '2024-06-14',
#    'temperature': 17.44,
#    'description': 'overcast clouds',
#    'wind_speed': 2.15,
#    'humidity': 89},
#   'assistant_response': 'The forecast for Palermo on 2024-06-14 is overcast clouds with a temperature of 17.44°C, wind speed of 2.15 meters per second, and humidity of 89%.'},
#  {'user_input': 'What is the forecast weather in Fukuoka 2024-06-11?',
#   'api_response': {'date': '2024-06-11',
#    'temperature': 24.28,
#    'description': 'overcast clouds',
#    'wind_speed': 0.62,
#    'humidity': 77},
#   'assistant_response': 'The forecast for Fukuoka on 2024-06-11 is overcast clouds with a temperature of 24.28°C, wind speed of 0.62 meters per second, and humidity of 77%.'},
#  {'user_input': 'What is the forecast weather in Nice 2024-06-13?',
#   'api_response': {'date': '2024-06-13',
#    'temperature': 7.98,
#    'description': 'light rain',
#    'wind_speed': 2.58,
#    'humidity': 89},
#   'assistant_response': 'The forecast for Nice on 2024-06-13 is light rain with a temperature of 7.98°C, wind speed of 2.58 meters per second, and humidity of 89%.'},
#  {'user_input': 'What is the forecast weather in San Diego 2024-06-14?',
#   'api_response': {'date': '2024-06-14',
#    'temperature': 21.22,
#    'description': 'clear sky',
#    'wind_speed': 4.05,
#    'humidity': 59},
#   'assistant_response': 'The forecast for San Diego on 2024-06-14 is clear sky with a temperature of 21.22°C, wind speed of 4.05 meters per second, and humidity of 59%.'},
#  {'user_input': 'What is the forecast weather in Rio de Janeiro 2024-06-11?',
#   'api_response': {'date': '2024-06-11',
#    'temperature': 22.51,
#    'description': 'few clouds',
#    'wind_speed': 1.36,
#    'humidity': 72},
#   'assistant_response': 'The forecast for Rio de Janeiro on 2024-06-11 is few clouds with a temperature of 22.51°C, wind speed of 1.36 meters per second, and humidity of 72%.'},
#  {'user_input': 'What is the current weather in Nagoya today?',
#   'api_response': {'location': 'Nagoya, JP',
#    'temperature': 22.04,
#    'description': 'broken clouds',
#    'wind_speed': 0.89,
#    'humidity': 82},
#   'assistant_response': 'The weather in Nagoya is currently broken clouds with a temperature of 22.04°C, wind speed of 0.89 meters per second, and humidity of 82%.'},
#  {'user_input': 'What is the current weather in Lagos today?',
#   'api_response': {'location': 'Lagos, NG',
#    'temperature': 32.18,
#    'description': 'light rain',
#    'wind_speed': 4.4,
#    'humidity': 71},
#   'assistant_response': 'The weather in Lagos is currently light rain with a temperature of 32.18°C, wind speed of 4.4 meters per second, and humidity of 71%.'},
#  {'user_input': 'What is the current weather in Manila today?',
#   'api_response': {'location': 'Manila, PH',
#    'temperature': 27.84,
#    'description': 'broken clouds',
#    'wind_speed': 0.45,
#    'humidity': 90},
#   'assistant_response': 'The weather in Manila is currently broken clouds with a temperature of 27.84°C, wind speed of 0.45 meters per second, and humidity of 90%.'},
#  {'user_input': 'What is the forecast weather in Nagoya 2024-06-15?',
#   'api_response': {'date': '2024-06-15',
#    'temperature': 24.91,
#    'description': 'overcast clouds',
#    'wind_speed': 2.43,
#    'humidity': 61},
#   'assistant_response': 'The forecast for Nagoya on 2024-06-15 is overcast clouds with a temperature of 24.91°C, wind speed of 2.43 meters per second, and humidity of 61%.'},
#  {'user_input': 'What is the forecast weather in Stuttgart 2024-06-14?',
#   'api_response': {'date': '2024-06-14',
#    'temperature': 11.36,
#    'description': 'broken clouds',
#    'wind_speed': 1.34,
#    'humidity': 83},
#   'assistant_response': 'The forecast for Stuttgart on 2024-06-14 is broken clouds with a temperature of 11.36°C, wind speed of 1.34 meters per second, and humidity of 83%.'},
#  {'user_input': 'What is the current weather in Vienna today?',
#   'api_response': {'location': 'Vienna, AT',
#    'temperature': 17.72,
#    'description': 'light rain',
#    'wind_speed': 3.6,
#    'humidity': 88},
#   'assistant_response': 'The weather in Vienna is currently light rain with a temperature of 17.72°C, wind speed of 3.6 meters per second, and humidity of 88%.'},
#  {'user_input': 'What is the forecast weather in Ankara 2024-06-14?',
#   'api_response': {'date': '2024-06-14',
#    'temperature': 23.02,
#    'description': 'broken clouds',
#    'wind_speed': 1.78,
#    'humidity': 55},
#   'assistant_response': 'The forecast for Ankara on 2024-06-14 is broken clouds with a temperature of 23.02°C, wind speed of 1.78 meters per second, and humidity of 55%.'},
#  {'user_input': 'What is the forecast weather in New York 2024-06-14?',
#   'api_response': {'date': '2024-06-14',
#    'temperature': 25.29,
#    'description': 'scattered clouds',
#    'wind_speed': 6.09,
#    'humidity': 60},
#   'assistant_response': 'The forecast for New York on 2024-06-14 is scattered clouds with a temperature of 25.29°C, wind speed of 6.09 meters per second, and humidity of 60%.'},
#  {'user_input': 'What is the forecast weather in Athens 2024-06-15?',
#   'api_response': {'date': '2024-06-15',
#    'temperature': 22.9,
#    'description': 'clear sky',
#    'wind_speed': 3.58,
#    'humidity': 77},
#   'assistant_response': 'The forecast for Athens on 2024-06-15 is clear sky with a temperature of 22.9°C, wind speed of 3.58 meters per second, and humidity of 77%.'},
#  {'user_input': 'What is the forecast weather in San Jose 2024-06-12?',
#   'api_response': {'date': '2024-06-12',
#    'temperature': 34.24,
#    'description': 'clear sky',
#    'wind_speed': 2.99,
#    'humidity': 20},
#   'assistant_response': 'The forecast for San Jose on 2024-06-12 is clear sky with a temperature of 34.24°C, wind speed of 2.99 meters per second, and humidity of 20%.'},
#  {'user_input': 'What is the forecast weather in Marseille 2024-06-14?',
#   'api_response': {'date': '2024-06-14',
#    'temperature': 16.47,
#    'description': 'scattered clouds',
#    'wind_speed': 0.76,
#    'humidity': 85},
#   'assistant_response': 'The forecast for Marseille on 2024-06-14 is scattered clouds with a temperature of 16.47°C, wind speed of 0.76 meters per second, and humidity of 85%.'},
#  {'user_input': 'What is the forecast weather in Florence 2024-06-15?',
#   'api_response': {'date': '2024-06-15',
#    'temperature': 16.56,
#    'description': 'overcast clouds',
#    'wind_speed': 0.88,
#    'humidity': 74},
#   'assistant_response': 'The forecast for Florence on 2024-06-15 is overcast clouds with a temperature of 16.56°C, wind speed of 0.88 meters per second, and humidity of 74%.'},
#  {'user_input': 'What is the forecast weather in Paris 2024-06-11?',
#   'api_response': {'date': '2024-06-11',
#    'temperature': 9.52,
#    'description': 'scattered clouds',
#    'wind_speed': 1.52,
#    'humidity': 84},
#   'assistant_response': 'The forecast for Paris on 2024-06-11 is scattered clouds with a temperature of 9.52°C, wind speed of 1.52 meters per second, and humidity of 84%.'},
#  {'user_input': 'What is the forecast weather in Yokohama 2024-06-12?',
#   'api_response': {'date': '2024-06-12',
#    'temperature': 22.8,
#    'description': 'overcast clouds',
#    'wind_speed': 2.87,
#    'humidity': 76},
#   'assistant_response': 'The forecast for Yokohama on 2024-06-12 is overcast clouds with a temperature of 22.8°C, wind speed of 2.87 meters per second, and humidity of 76%.'},
#  {'user_input': 'What is the current weather in Berlin today?',
#   'api_response': {'location': 'Berlin, DE',
#    'temperature': 19.39,
#    'description': 'clear sky',
#    'wind_speed': 3.58,
#    'humidity': 46},
#   'assistant_response': 'The weather in Berlin is currently clear sky with a temperature of 19.39°C, wind speed of 3.58 meters per second, and humidity of 46%.'},
#  {'user_input': 'What is the forecast weather in Sendai 2024-06-15?',
#   'api_response': {'date': '2024-06-15',
#    'temperature': 23.46,
#    'description': 'few clouds',
#    'wind_speed': 2.49,
#    'humidity': 71},
#   'assistant_response': 'The forecast for Sendai on 2024-06-15 is few clouds with a temperature of 23.46°C, wind speed of 2.49 meters per second, and humidity of 71%.'},
#  {'user_input': 'What is the current weather in Toulouse today?',
#   'api_response': {'location': 'Toulouse, FR',
#    'temperature': 23.99,
#    'description': 'scattered clouds',
#    'wind_speed': 5.66,
#    'humidity': 43},
#   'assistant_response': 'The weather in Toulouse is currently scattered clouds with a temperature of 23.99°C, wind speed of 5.66 meters per second, and humidity of 43%.'},
#  {'user_input': 'What is the forecast weather in Milan 2024-06-12?',
#   'api_response': {'date': '2024-06-12',
#    'temperature': 15.27,
#    'description': 'moderate rain',
#    'wind_speed': 3.19,
#    'humidity': 97},
#   'assistant_response': 'The forecast for Milan on 2024-06-12 is moderate rain with a temperature of 15.27°C, wind speed of 3.19 meters per second, and humidity of 97%.'},
#  {'user_input': 'What is the forecast weather in Beijing 2024-06-13?',
#   'api_response': {'date': '2024-06-13',
#    'temperature': 27.85,
#    'description': 'broken clouds',
#    'wind_speed': 2.05,
#    'humidity': 50},
#   'assistant_response': 'The forecast for Beijing on 2024-06-13 is broken clouds with a temperature of 27.85°C, wind speed of 2.05 meters per second, and humidity of 50%.'},
#  {'user_input': 'What is the current weather in Frankfurt today?',
#   'api_response': {'location': 'Frankfurt, DE',
#    'temperature': 19.78,
#    'description': 'light rain',
#    'wind_speed': 7.72,
#    'humidity': 50},
#   'assistant_response': 'The weather in Frankfurt is currently light rain with a temperature of 19.78°C, wind speed of 7.72 meters per second, and humidity of 50%.'},
#  {'user_input': 'What is the current weather in Brisbane today?',
#   'api_response': {'location': 'Brisbane, AU',
#    'temperature': 10.58,
#    'description': 'clear sky',
#    'wind_speed': 2.57,
#    'humidity': 83},
#   'assistant_response': 'The weather in Brisbane is currently clear sky with a temperature of 10.58°C, wind speed of 2.57 meters per second, and humidity of 83%.'},
#  {'user_input': 'What is the current weather in Marseille today?',
#   'api_response': {'location': 'Marseille, FR',
#    'temperature': 22.95,
#    'description': 'scattered clouds',
#    'wind_speed': 6.26,
#    'humidity': 35},
#   'assistant_response': 'The weather in Marseille is currently scattered clouds with a temperature of 22.95°C, wind speed of 6.26 meters per second, and humidity of 35%.'},
#  {'user_input': 'What is the forecast weather in Helsinki 2024-06-13?',
#   'api_response': {'date': '2024-06-13',
#    'temperature': 9.51,
#    'description': 'few clouds',
#    'wind_speed': 2.39,
#    'humidity': 92},
#   'assistant_response': 'The forecast for Helsinki on 2024-06-13 is few clouds with a temperature of 9.51°C, wind speed of 2.39 meters per second, and humidity of 92%.'},
#  {'user_input': 'What is the current weather in Milan today?',
#   'api_response': {'location': 'Milan, IT',
#    'temperature': 27.46,
#    'description': 'few clouds',
#    'wind_speed': 4.63,
#    'humidity': 55},
#   'assistant_response': 'The weather in Milan is currently few clouds with a temperature of 27.46°C, wind speed of 4.63 meters per second, and humidity of 55%.'},
#  {'user_input': 'What is the forecast weather in Mumbai 2024-06-13?',
#   'api_response': {'date': '2024-06-13',
#    'temperature': 28.54,
#    'description': 'few clouds',
#    'wind_speed': 5.06,
#    'humidity': 76},
#   'assistant_response': 'The forecast for Mumbai on 2024-06-13 is few clouds with a temperature of 28.54°C, wind speed of 5.06 meters per second, and humidity of 76%.'},
#  {'user_input': 'What is the forecast weather in Abu Dhabi 2024-06-15?',
#   'api_response': {'date': '2024-06-15',
#    'temperature': 31.42,
#    'description': 'clear sky',
#    'wind_speed': 1.61,
#    'humidity': 65},
#   'assistant_response': 'The forecast for Abu Dhabi on 2024-06-15 is clear sky with a temperature of 31.42°C, wind speed of 1.61 meters per second, and humidity of 65%.'},
#  {'user_input': 'What is the current weather in Stuttgart today?',
#   'api_response': {'location': 'Stuttgart, DE',
#    'temperature': 21.74,
#    'description': 'light rain',
#    'wind_speed': 6.17,
#    'humidity': 45},
#   'assistant_response': 'The weather in Stuttgart is currently light rain with a temperature of 21.74°C, wind speed of 6.17 meters per second, and humidity of 45%.'},
#  {'user_input': 'What is the forecast weather in Jakarta 2024-06-14?',
#   'api_response': {'date': '2024-06-14',
#    'temperature': 25.1,
#    'description': 'overcast clouds',
#    'wind_speed': 2.26,
#    'humidity': 87},
#   'assistant_response': 'The forecast for Jakarta on 2024-06-14 is overcast clouds with a temperature of 25.1°C, wind speed of 2.26 meters per second, and humidity of 87%.'},
#  {'user_input': 'What is the forecast weather in Fukuoka 2024-06-15?',
#   'api_response': {'date': '2024-06-15',
#    'temperature': 22.74,
#    'description': 'overcast clouds',
#    'wind_speed': 1.36,
#    'humidity': 71},
#   'assistant_response': 'The forecast for Fukuoka on 2024-06-15 is overcast clouds with a temperature of 22.74°C, wind speed of 1.36 meters per second, and humidity of 71%.'},
#  {'user_input': 'What is the forecast weather in Fukuoka 2024-06-13?',
#   'api_response': {'date': '2024-06-13',
#    'temperature': 25.64,
#    'description': 'clear sky',
#    'wind_speed': 1.01,
#    'humidity': 68},
#   'assistant_response': 'The forecast for Fukuoka on 2024-06-13 is clear sky with a temperature of 25.64°C, wind speed of 1.01 meters per second, and humidity of 68%.'},
#  {'user_input': 'What is the forecast weather in Beijing 2024-06-11?',
#   'api_response': {'date': '2024-06-11',
#    'temperature': 28.49,
#    'description': 'scattered clouds',
#    'wind_speed': 1.86,
#    'humidity': 36},
#   'assistant_response': 'The forecast for Beijing on 2024-06-11 is scattered clouds with a temperature of 28.49°C, wind speed of 1.86 meters per second, and humidity of 36%.'},
#  {'user_input': 'What is the current weather in Riyadh today?',
#   'api_response': {'location': 'Riyadh, SA',
#    'temperature': 43.08,
#    'description': 'clear sky',
#    'wind_speed': 4.03,
#    'humidity': 7},
#   'assistant_response': 'The weather in Riyadh is currently clear sky with a temperature of 43.08°C, wind speed of 4.03 meters per second, and humidity of 7%.'},
#  {'user_input': 'What is the forecast weather in Florence 2024-06-11?',
#   'api_response': {'date': '2024-06-11',
#    'temperature': 17.18,
#    'description': 'clear sky',
#    'wind_speed': 1.8,
#    'humidity': 87},
#   'assistant_response': 'The forecast for Florence on 2024-06-11 is clear sky with a temperature of 17.18°C, wind speed of 1.8 meters per second, and humidity of 87%.'},
#  {'user_input': 'What is the forecast weather in Moscow 2024-06-15?',
#   'api_response': {'date': '2024-06-15',
#    'temperature': 14.74,
#    'description': 'clear sky',
#    'wind_speed': 2.27,
#    'humidity': 74},
#   'assistant_response': 'The forecast for Moscow on 2024-06-15 is clear sky with a temperature of 14.74°C, wind speed of 2.27 meters per second, and humidity of 74%.'},
#  {'user_input': 'What is the forecast weather in Vienna 2024-06-15?',
#   'api_response': {'date': '2024-06-15',
#    'temperature': 15.57,
#    'description': 'broken clouds',
#    'wind_speed': 0.81,
#    'humidity': 82},
#   'assistant_response': 'The forecast for Vienna on 2024-06-15 is broken clouds with a temperature of 15.57°C, wind speed of 0.81 meters per second, and humidity of 82%.'},
#  {'user_input': 'What is the forecast weather in Lyon 2024-06-14?',
#   'api_response': {'date': '2024-06-14',
#    'temperature': 9.67,
#    'description': 'broken clouds',
#    'wind_speed': 1.28,
#    'humidity': 82},
#   'assistant_response': 'The forecast for Lyon on 2024-06-14 is broken clouds with a temperature of 9.67°C, wind speed of 1.28 meters per second, and humidity of 82%.'},
#  {'user_input': 'What is the forecast weather in Hiroshima 2024-06-11?',
#   'api_response': {'date': '2024-06-11',
#    'temperature': 23.1,
#    'description': 'overcast clouds',
#    'wind_speed': 0.79,
#    'humidity': 80},
#   'assistant_response': 'The forecast for Hiroshima on 2024-06-11 is overcast clouds with a temperature of 23.1°C, wind speed of 0.79 meters per second, and humidity of 80%.'},
#  {'user_input': 'What is the forecast weather in Seoul 2024-06-13?',
#   'api_response': {'date': '2024-06-13',
#    'temperature': 25.4,
#    'description': 'clear sky',
#    'wind_speed': 0.83,
#    'humidity': 51},
#   'assistant_response': 'The forecast for Seoul on 2024-06-13 is clear sky with a temperature of 25.4°C, wind speed of 0.83 meters per second, and humidity of 51%.'},
#  {'user_input': 'What is the current weather in Paris today?',
#   'api_response': {'location': 'Paris, FR',
#    'temperature': 16.77,
#    'description': 'light rain',
#    'wind_speed': 7.2,
#    'humidity': 65},
#   'assistant_response': 'The weather in Paris is currently light rain with a temperature of 16.77°C, wind speed of 7.2 meters per second, and humidity of 65%.'},
#  {'user_input': 'What is the forecast weather in Istanbul 2024-06-14?',
#   'api_response': {'date': '2024-06-14',
#    'temperature': 22.22,
#    'description': 'scattered clouds',
#    'wind_speed': 1.82,
#    'humidity': 74},
#   'assistant_response': 'The forecast for Istanbul on 2024-06-14 is scattered clouds with a temperature of 22.22°C, wind speed of 1.82 meters per second, and humidity of 74%.'},
#  {'user_input': 'What is the current weather in Phoenix today?',
#   'api_response': {'location': 'Phoenix, US',
#    'temperature': 30.72,
#    'description': 'few clouds',
#    'wind_speed': 2.06,
#    'humidity': 20},
#   'assistant_response': 'The weather in Phoenix is currently few clouds with a temperature of 30.72°C, wind speed of 2.06 meters per second, and humidity of 20%.'},
#  {'user_input': 'What is the forecast weather in Madrid 2024-06-14?',
#   'api_response': {'date': '2024-06-14',
#    'temperature': 22.11,
#    'description': 'broken clouds',
#    'wind_speed': 3.56,
#    'humidity': 27},
#   'assistant_response': 'The forecast for Madrid on 2024-06-14 is broken clouds with a temperature of 22.11°C, wind speed of 3.56 meters per second, and humidity of 27%.'},
#  {'user_input': 'What is the current weather in Vienna today?',
#   'api_response': {'location': 'Vienna, AT',
#    'temperature': 17.72,
#    'description': 'light rain',
#    'wind_speed': 3.6,
#    'humidity': 88},
#   'assistant_response': 'The weather in Vienna is currently light rain with a temperature of 17.72°C, wind speed of 3.6 meters per second, and humidity of 88%.'},
#  {'user_input': 'What is the current weather in Glasgow today?',
#   'api_response': {'location': 'Glasgow, GB',
#    'temperature': 14.48,
#    'description': 'moderate rain',
#    'wind_speed': 8.75,
#    'humidity': 56},
#   'assistant_response': 'The weather in Glasgow is currently moderate rain with a temperature of 14.48°C, wind speed of 8.75 meters per second, and humidity of 56%.'},
#  {'user_input': 'What is the current weather in Casablanca today?',
#   'api_response': {'location': 'Casablanca, MA',
#    'temperature': 22.96,
#    'description': 'scattered clouds',
#    'wind_speed': 4.92,
#    'humidity': 60},
#   'assistant_response': 'The weather in Casablanca is currently scattered clouds with a temperature of 22.96°C, wind speed of 4.92 meters per second, and humidity of 60%.'},
#  {'user_input': 'What is the current weather in Santiago today?',
#   'api_response': {'location': 'Santiago, CL',
#    'temperature': 12.99,
#    'description': 'overcast clouds',
#    'wind_speed': 0.51,
#    'humidity': 82},
#   'assistant_response': 'The weather in Santiago is currently overcast clouds with a temperature of 12.99°C, wind speed of 0.51 meters per second, and humidity of 82%.'},
#  {'user_input': 'What is the current weather in New York today?',
#   'api_response': {'location': 'New York, US',
#    'temperature': 21.11,
#    'description': 'broken clouds',
#    'wind_speed': 7.15,
#    'humidity': 49},
#   'assistant_response': 'The weather in New York is currently broken clouds with a temperature of 21.11°C, wind speed of 7.15 meters per second, and humidity of 49%.'},
#  {'user_input': 'What is the current weather in Cairo today?',
#   'api_response': {'location': 'Cairo, EG',
#    'temperature': 36.42,
#    'description': 'clear sky',
#    'wind_speed': 3.6,
#    'humidity': 26},
#   'assistant_response': 'The weather in Cairo is currently clear sky with a temperature of 36.42°C, wind speed of 3.6 meters per second, and humidity of 26%.'},
#  {'user_input': 'What is the forecast weather in Helsinki 2024-06-14?',
#   'api_response': {'date': '2024-06-14',
#    'temperature': 9.33,
#    'description': 'broken clouds',
#    'wind_speed': 0.69,
#    'humidity': 82},
#   'assistant_response': 'The forecast for Helsinki on 2024-06-14 is broken clouds with a temperature of 9.33°C, wind speed of 0.69 meters per second, and humidity of 82%.'},
#  {'user_input': 'What is the forecast weather in San Antonio 2024-06-15?',
#   'api_response': {'date': '2024-06-15',
#    'temperature': 33.87,
#    'description': 'few clouds',
#    'wind_speed': 8.05,
#    'humidity': 42},
#   'assistant_response': 'The forecast for San Antonio on 2024-06-15 is few clouds with a temperature of 33.87°C, wind speed of 8.05 meters per second, and humidity of 42%.'},
#  {'user_input': 'What is the current weather in Milan today?',
#   'api_response': {'location': 'Milan, IT',
#    'temperature': 27.46,
#    'description': 'few clouds',
#    'wind_speed': 4.63,
#    'humidity': 55},
#   'assistant_response': 'The weather in Milan is currently few clouds with a temperature of 27.46°C, wind speed of 4.63 meters per second, and humidity of 55%.'},
#  {'user_input': 'What is the current weather in Chicago today?',
#   'api_response': {'location': 'Chicago, US',
#    'temperature': 15.56,
#    'description': 'broken clouds',
#    'wind_speed': 6.17,
#    'humidity': 61},
#   'assistant_response': 'The weather in Chicago is currently broken clouds with a temperature of 15.56°C, wind speed of 6.17 meters per second, and humidity of 61%.'},
#  {'user_input': 'What is the current weather in Lima today?',
#   'api_response': {'location': 'Lima, PE',
#    'temperature': 17.48,
#    'description': 'overcast clouds',
#    'wind_speed': 4.12,
#    'humidity': 80},
#   'assistant_response': 'The weather in Lima is currently overcast clouds with a temperature of 17.48°C, wind speed of 4.12 meters per second, and humidity of 80%.'},
#  {'user_input': 'What is the current weather in Ankara today?',
#   'api_response': {'location': 'Ankara, TR',
#    'temperature': 29,
#    'description': 'clear sky',
#    'wind_speed': 0.45,
#    'humidity': 29},
#   'assistant_response': 'The weather in Ankara is currently clear sky with a temperature of 29°C, wind speed of 0.45 meters per second, and humidity of 29%.'},
#  {'user_input': 'What is the current weather in Addis Ababa today?',
#   'api_response': {'location': 'Addis Ababa, ET',
#    'temperature': 22.6,
#    'description': 'overcast clouds',
#    'wind_speed': 2.37,
#    'humidity': 35},
#   'assistant_response': 'The weather in Addis Ababa is currently overcast clouds with a temperature of 22.6°C, wind speed of 2.37 meters per second, and humidity of 35%.'},
#  {'user_input': 'What is the current weather in Dallas today?',
#   'api_response': {'location': 'Dallas, US',
#    'temperature': 26.73,
#    'description': 'overcast clouds',
#    'wind_speed': 1.54,
#    'humidity': 80},
#   'assistant_response': 'The weather in Dallas is currently overcast clouds with a temperature of 26.73°C, wind speed of 1.54 meters per second, and humidity of 80%.'},
#  {'user_input': 'What is the current weather in Cairo today?',
#   'api_response': {'location': 'Cairo, EG',
#    'temperature': 36.42,
#    'description': 'clear sky',
#    'wind_speed': 3.6,
#    'humidity': 26},
#   'assistant_response': 'The weather in Cairo is currently clear sky with a temperature of 36.42°C, wind speed of 3.6 meters per second, and humidity of 26%.'},
#  {'user_input': 'What is the forecast weather in Kyoto 2024-06-12?',
#   'api_response': {'date': '2024-06-12',
#    'temperature': 25.9,
#    'description': 'overcast clouds',
#    'wind_speed': 0.96,
#    'humidity': 64},
#   'assistant_response': 'The forecast for Kyoto on 2024-06-12 is overcast clouds with a temperature of 25.9°C, wind speed of 0.96 meters per second, and humidity of 64%.'},
#  {'user_input': 'What is the forecast weather in Hong Kong 2024-06-12?',
#   'api_response': {'date': '2024-06-12',
#    'temperature': 27.95,
#    'description': 'light rain',
#    'wind_speed': 3.35,
#    'humidity': 88},
#   'assistant_response': 'The forecast for Hong Kong on 2024-06-12 is light rain with a temperature of 27.95°C, wind speed of 3.35 meters per second, and humidity of 88%.'},
#  {'user_input': 'What is the forecast weather in Vienna 2024-06-13?',
#   'api_response': {'date': '2024-06-13',
#    'temperature': 9.97,
#    'description': 'broken clouds',
#    'wind_speed': 1.42,
#    'humidity': 94},
#   'assistant_response': 'The forecast for Vienna on 2024-06-13 is broken clouds with a temperature of 9.97°C, wind speed of 1.42 meters per second, and humidity of 94%.'},
#  {'user_input': 'What is the forecast weather in Athens 2024-06-15?',
#   'api_response': {'date': '2024-06-15',
#    'temperature': 22.9,
#    'description': 'clear sky',
#    'wind_speed': 3.58,
#    'humidity': 77},
#   'assistant_response': 'The forecast for Athens on 2024-06-15 is clear sky with a temperature of 22.9°C, wind speed of 3.58 meters per second, and humidity of 77%.'},
#  {'user_input': 'What is the current weather in Shanghai today?',
#   'api_response': {'location': 'Shanghai, CN',
#    'temperature': 21.76,
#    'description': 'broken clouds',
#    'wind_speed': 5,
#    'humidity': 91},
#   'assistant_response': 'The weather in Shanghai is currently broken clouds with a temperature of 21.76°C, wind speed of 5 meters per second, and humidity of 91%.'},
#  {'user_input': 'What is the forecast weather in Edinburgh 2024-06-12?',
#   'api_response': {'date': '2024-06-12',
#    'temperature': 7.69,
#    'description': 'broken clouds',
#    'wind_speed': 1.71,
#    'humidity': 80},
#   'assistant_response': 'The forecast for Edinburgh on 2024-06-12 is broken clouds with a temperature of 7.69°C, wind speed of 1.71 meters per second, and humidity of 80%.'},
#  {'user_input': 'What is the forecast weather in Seoul 2024-06-15?',
#   'api_response': {'date': '2024-06-15',
#    'temperature': 25.11,
#    'description': 'light rain',
#    'wind_speed': 0.66,
#    'humidity': 64},
#   'assistant_response': 'The forecast for Seoul on 2024-06-15 is light rain with a temperature of 25.11°C, wind speed of 0.66 meters per second, and humidity of 64%.'},
#  {'user_input': 'What is the current weather in Milan today?',
#   'api_response': {'location': 'Milan, IT',
#    'temperature': 27.46,
#    'description': 'few clouds',
#    'wind_speed': 4.63,
#    'humidity': 55},
#   'assistant_response': 'The weather in Milan is currently few clouds with a temperature of 27.46°C, wind speed of 4.63 meters per second, and humidity of 55%.'},
#  {'user_input': 'What is the current weather in Lyon today?',
#   'api_response': {'location': 'Lyon, FR',
#    'temperature': 19.83,
#    'description': 'clear sky',
#    'wind_speed': 3.66,
#    'humidity': 53},
#   'assistant_response': 'The weather in Lyon is currently clear sky with a temperature of 19.83°C, wind speed of 3.66 meters per second, and humidity of 53%.'},
#  {'user_input': 'What is the forecast weather in Zurich 2024-06-11?',
#   'api_response': {'date': '2024-06-11',
#    'temperature': 12.71,
#    'description': 'light rain',
#    'wind_speed': 0.77,
#    'humidity': 86},
#   'assistant_response': 'The forecast for Zurich on 2024-06-11 is light rain with a temperature of 12.71°C, wind speed of 0.77 meters per second, and humidity of 86%.'},
#  {'user_input': 'What is the forecast weather in Cairo 2024-06-12?',
#   'api_response': {'date': '2024-06-12',
#    'temperature': 26.51,
#    'description': 'clear sky',
#    'wind_speed': 4.36,
#    'humidity': 41},
#   'assistant_response': 'The forecast for Cairo on 2024-06-12 is clear sky with a temperature of 26.51°C, wind speed of 4.36 meters per second, and humidity of 41%.'},
#  {'user_input': 'What is the forecast weather in Shanghai 2024-06-13?',
#   'api_response': {'date': '2024-06-13',
#    'temperature': 25.25,
#    'description': 'broken clouds',
#    'wind_speed': 2.53,
#    'humidity': 76},
#   'assistant_response': 'The forecast for Shanghai on 2024-06-13 is broken clouds with a temperature of 25.25°C, wind speed of 2.53 meters per second, and humidity of 76%.'},
#  {'user_input': 'What is the current weather in Nice today?',
#   'api_response': {'location': 'Nice, FR',
#    'temperature': 17.88,
#    'description': 'light rain',
#    'wind_speed': 1.93,
#    'humidity': 78},
#   'assistant_response': 'The weather in Nice is currently light rain with a temperature of 17.88°C, wind speed of 1.93 meters per second, and humidity of 78%.'},
#  {'user_input': 'What is the current weather in London today?',
#   'api_response': {'location': 'London, GB',
#    'temperature': 14.45,
#    'description': 'scattered clouds',
#    'wind_speed': 5.66,
#    'humidity': 67},
#   'assistant_response': 'The weather in London is currently scattered clouds with a temperature of 14.45°C, wind speed of 5.66 meters per second, and humidity of 67%.'},
#  {'user_input': 'What is the forecast weather in Oslo 2024-06-15?',
#   'api_response': {'date': '2024-06-15',
#    'temperature': 7.45,
#    'description': 'broken clouds',
#    'wind_speed': 0.09,
#    'humidity': 96},
#   'assistant_response': 'The forecast for Oslo on 2024-06-15 is broken clouds with a temperature of 7.45°C, wind speed of 0.09 meters per second, and humidity of 96%.'},
#  {'user_input': 'What is the forecast weather in Hong Kong 2024-06-14?',
#   'api_response': {'date': '2024-06-14',
#    'temperature': 28.24,
#    'description': 'moderate rain',
#    'wind_speed': 8.5,
#    'humidity': 87},
#   'assistant_response': 'The forecast for Hong Kong on 2024-06-14 is moderate rain with a temperature of 28.24°C, wind speed of 8.5 meters per second, and humidity of 87%.'},
#  {'user_input': 'What is the forecast weather in Florence 2024-06-14?',
#   'api_response': {'date': '2024-06-14',
#    'temperature': 15.46,
#    'description': 'clear sky',
#    'wind_speed': 0.71,
#    'humidity': 82},
#   'assistant_response': 'The forecast for Florence on 2024-06-14 is clear sky with a temperature of 15.46°C, wind speed of 0.71 meters per second, and humidity of 82%.'},
#  {'user_input': 'What is the forecast weather in Vienna 2024-06-12?',
#   'api_response': {'date': '2024-06-12',
#    'temperature': 13.24,
#    'description': 'light rain',
#    'wind_speed': 2.75,
#    'humidity': 86},
#   'assistant_response': 'The forecast for Vienna on 2024-06-12 is light rain with a temperature of 13.24°C, wind speed of 2.75 meters per second, and humidity of 86%.'},
#  {'user_input': 'What is the current weather in Stuttgart today?',
#   'api_response': {'location': 'Stuttgart, DE',
#    'temperature': 21.74,
#    'description': 'light rain',
#    'wind_speed': 6.17,
#    'humidity': 45},
#   'assistant_response': 'The weather in Stuttgart is currently light rain with a temperature of 21.74°C, wind speed of 6.17 meters per second, and humidity of 45%.'},
#  {'user_input': 'What is the forecast weather in Brisbane 2024-06-14?',
#   'api_response': {'date': '2024-06-14',
#    'temperature': 16.07,
#    'description': 'few clouds',
#    'wind_speed': 2.61,
#    'humidity': 40},
#   'assistant_response': 'The forecast for Brisbane on 2024-06-14 is few clouds with a temperature of 16.07°C, wind speed of 2.61 meters per second, and humidity of 40%.'},
#  {'user_input': 'What is the forecast weather in San Jose 2024-06-13?',
#   'api_response': {'date': '2024-06-13',
#    'temperature': 29.34,
#    'description': 'clear sky',
#    'wind_speed': 2.55,
#    'humidity': 26},
#   'assistant_response': 'The forecast for San Jose on 2024-06-13 is clear sky with a temperature of 29.34°C, wind speed of 2.55 meters per second, and humidity of 26%.'},
#  {'user_input': 'What is the current weather in Shanghai today?',
#   'api_response': {'location': 'Shanghai, CN',
#    'temperature': 21.76,
#    'description': 'broken clouds',
#    'wind_speed': 5,
#    'humidity': 91},
#   'assistant_response': 'The weather in Shanghai is currently broken clouds with a temperature of 21.76°C, wind speed of 5 meters per second, and humidity of 91%.'},
#  {'user_input': 'What is the current weather in Warsaw today?',
#   'api_response': {'location': 'Warsaw, PL',
#    'temperature': 22.04,
#    'description': 'light rain',
#    'wind_speed': 4.12,
#    'humidity': 62},
#   'assistant_response': 'The weather in Warsaw is currently light rain with a temperature of 22.04°C, wind speed of 4.12 meters per second, and humidity of 62%.'},
#  {'user_input': 'What is the current weather in Frankfurt today?',
#   'api_response': {'location': 'Frankfurt, DE',
#    'temperature': 19.78,
#    'description': 'light rain',
#    'wind_speed': 7.72,
#    'humidity': 50},
#   'assistant_response': 'The weather in Frankfurt is currently light rain with a temperature of 19.78°C, wind speed of 7.72 meters per second, and humidity of 50%.'},
#  {'user_input': 'What is the current weather in Rio de Janeiro today?',
#   'api_response': {'location': 'Rio de Janeiro, BR',
#    'temperature': 25.98,
#    'description': 'clear sky',
#    'wind_speed': 2.57,
#    'humidity': 73},
#   'assistant_response': 'The weather in Rio de Janeiro is currently clear sky with a temperature of 25.98°C, wind speed of 2.57 meters per second, and humidity of 73%.'},
#  {'user_input': 'What is the current weather in Hamburg today?',
#   'api_response': {'location': 'Hamburg, DE',
#    'temperature': 12.9,
#    'description': 'light rain',
#    'wind_speed': 1.54,
#    'humidity': 88},
#   'assistant_response': 'The weather in Hamburg is currently light rain with a temperature of 12.9°C, wind speed of 1.54 meters per second, and humidity of 88%.'},
#  {'user_input': 'What is the forecast weather in Dhaka 2024-06-15?',
#   'api_response': {'date': '2024-06-15',
#    'temperature': 27.9,
#    'description': 'light rain',
#    'wind_speed': 4.44,
#    'humidity': 87},
#   'assistant_response': 'The forecast for Dhaka on 2024-06-15 is light rain with a temperature of 27.9°C, wind speed of 4.44 meters per second, and humidity of 87%.'},
#  {'user_input': 'What is the forecast weather in Osaka 2024-06-11?',
#   'api_response': {'date': '2024-06-11',
#    'temperature': 23.97,
#    'description': 'broken clouds',
#    'wind_speed': 1.74,
#    'humidity': 67},
#   'assistant_response': 'The forecast for Osaka on 2024-06-11 is broken clouds with a temperature of 23.97°C, wind speed of 1.74 meters per second, and humidity of 67%.'},
#  {'user_input': 'What is the forecast weather in Stockholm 2024-06-14?',
#   'api_response': {'date': '2024-06-14',
#    'temperature': 8.97,
#    'description': 'scattered clouds',
#    'wind_speed': 2.06,
#    'humidity': 93},
#   'assistant_response': 'The forecast for Stockholm on 2024-06-14 is scattered clouds with a temperature of 8.97°C, wind speed of 2.06 meters per second, and humidity of 93%.'},
#  {'user_input': 'What is the current weather in Ankara today?',
#   'api_response': {'location': 'Ankara, TR',
#    'temperature': 29,
#    'description': 'clear sky',
#    'wind_speed': 0.45,
#    'humidity': 29},
#   'assistant_response': 'The weather in Ankara is currently clear sky with a temperature of 29°C, wind speed of 0.45 meters per second, and humidity of 29%.'},
#  {'user_input': 'What is the forecast weather in Los Angeles 2024-06-12?',
#   'api_response': {'date': '2024-06-12',
#    'temperature': 24.61,
#    'description': 'clear sky',
#    'wind_speed': 4.11,
#    'humidity': 48},
#   'assistant_response': 'The forecast for Los Angeles on 2024-06-12 is clear sky with a temperature of 24.61°C, wind speed of 4.11 meters per second, and humidity of 48%.'},
#  {'user_input': 'What is the forecast weather in Dubai 2024-06-15?',
#   'api_response': {'date': '2024-06-15',
#    'temperature': 31.52,
#    'description': 'clear sky',
#    'wind_speed': 3.78,
#    'humidity': 60},
#   'assistant_response': 'The forecast for Dubai on 2024-06-15 is clear sky with a temperature of 31.52°C, wind speed of 3.78 meters per second, and humidity of 60%.'},
#  {'user_input': 'What is the current weather in Glasgow today?',
#   'api_response': {'location': 'Glasgow, GB',
#    'temperature': 14.48,
#    'description': 'moderate rain',
#    'wind_speed': 8.75,
#    'humidity': 56},
#   'assistant_response': 'The weather in Glasgow is currently moderate rain with a temperature of 14.48°C, wind speed of 8.75 meters per second, and humidity of 56%.'},
#  {'user_input': 'What is the current weather in Venice today?',
#   'api_response': {'location': 'Venice, US',
#    'temperature': 30.81,
#    'description': 'few clouds',
#    'wind_speed': 1.54,
#    'humidity': 87},
#   'assistant_response': 'The weather in Venice is currently few clouds with a temperature of 30.81°C, wind speed of 1.54 meters per second, and humidity of 87%.'},
#  {'user_input': 'What is the forecast weather in Sydney 2024-06-14?',
#   'api_response': {'date': '2024-06-14',
#    'temperature': 12.49,
#    'description': 'light rain',
#    'wind_speed': 6.08,
#    'humidity': 75},
#   'assistant_response': 'The forecast for Sydney on 2024-06-14 is light rain with a temperature of 12.49°C, wind speed of 6.08 meters per second, and humidity of 75%.'},
#  {'user_input': 'What is the forecast weather in Lima 2024-06-12?',
#   'api_response': {'date': '2024-06-12',
#    'temperature': 18.43,
#    'description': 'overcast clouds',
#    'wind_speed': 2.05,
#    'humidity': 77},
#   'assistant_response': 'The forecast for Lima on 2024-06-12 is overcast clouds with a temperature of 18.43°C, wind speed of 2.05 meters per second, and humidity of 77%.'},
#  {'user_input': 'What is the forecast weather in San Antonio 2024-06-11?',
#   'api_response': {'date': '2024-06-11',
#    'temperature': 31.98,
#    'description': 'light rain',
#    'wind_speed': 3.92,
#    'humidity': 47},
#   'assistant_response': 'The forecast for San Antonio on 2024-06-11 is light rain with a temperature of 31.98°C, wind speed of 3.92 meters per second, and humidity of 47%.'},
#  {'user_input': 'What is the current weather in Lagos today?',
#   'api_response': {'location': 'Lagos, NG',
#    'temperature': 32.18,
#    'description': 'light rain',
#    'wind_speed': 4.4,
#    'humidity': 71},
#   'assistant_response': 'The weather in Lagos is currently light rain with a temperature of 32.18°C, wind speed of 4.4 meters per second, and humidity of 71%.'},
#  {'user_input': 'What is the forecast weather in Dallas 2024-06-14?',
#   'api_response': {'date': '2024-06-14',
#    'temperature': 31.25,
#    'description': 'clear sky',
#    'wind_speed': 3.58,
#    'humidity': 55},
#   'assistant_response': 'The forecast for Dallas on 2024-06-14 is clear sky with a temperature of 31.25°C, wind speed of 3.58 meters per second, and humidity of 55%.'},
#  {'user_input': 'What is the forecast weather in Yokohama 2024-06-15?',
#   'api_response': {'date': '2024-06-15',
#    'temperature': 23.08,
#    'description': 'scattered clouds',
#    'wind_speed': 3.3,
#    'humidity': 74},
#   'assistant_response': 'The forecast for Yokohama on 2024-06-15 is scattered clouds with a temperature of 23.08°C, wind speed of 3.3 meters per second, and humidity of 74%.'},
#  {'user_input': 'What is the current weather in Abu Dhabi today?',
#   'api_response': {'location': 'Abu Dhabi, AE',
#    'temperature': 36.01,
#    'description': 'clear sky',
#    'wind_speed': 3.09,
#    'humidity': 52},
#   'assistant_response': 'The weather in Abu Dhabi is currently clear sky with a temperature of 36.01°C, wind speed of 3.09 meters per second, and humidity of 52%.'},
#  {'user_input': 'What is the current weather in Bangkok today?',
#   'api_response': {'location': 'Bangkok, TH',
#    'temperature': 29.94,
#    'description': 'overcast clouds',
#    'wind_speed': 4.34,
#    'humidity': 78},
#   'assistant_response': 'The weather in Bangkok is currently overcast clouds with a temperature of 29.94°C, wind speed of 4.34 meters per second, and humidity of 78%.'},
#  {'user_input': 'What is the forecast weather in Lagos 2024-06-12?',
#   'api_response': {'date': '2024-06-12',
#    'temperature': 25.36,
#    'description': 'light rain',
#    'wind_speed': 1.47,
#    'humidity': 91},
#   'assistant_response': 'The forecast for Lagos on 2024-06-12 is light rain with a temperature of 25.36°C, wind speed of 1.47 meters per second, and humidity of 91%.'},
#  {'user_input': 'What is the forecast weather in Turin 2024-06-15?',
#   'api_response': {'date': '2024-06-15',
#    'temperature': 12.2,
#    'description': 'broken clouds',
#    'wind_speed': 2.63,
#    'humidity': 70},
#   'assistant_response': 'The forecast for Turin on 2024-06-15 is broken clouds with a temperature of 12.2°C, wind speed of 2.63 meters per second, and humidity of 70%.'},
#  {'user_input': 'What is the current weather in Sydney today?',
#   'api_response': {'location': 'Sydney, AU',
#    'temperature': 9.19,
#    'description': 'overcast clouds',
#    'wind_speed': 4.63,
#    'humidity': 82},
#   'assistant_response': 'The weather in Sydney is currently overcast clouds with a temperature of 9.19°C, wind speed of 4.63 meters per second, and humidity of 82%.'},
#  {'user_input': 'What is the current weather in Copenhagen today?',
#   'api_response': {'location': 'Copenhagen, DK',
#    'temperature': 16.48,
#    'description': 'broken clouds',
#    'wind_speed': 8.23,
#    'humidity': 58},
#   'assistant_response': 'The weather in Copenhagen is currently broken clouds with a temperature of 16.48°C, wind speed of 8.23 meters per second, and humidity of 58%.'},
#  {'user_input': 'What is the forecast weather in Rome 2024-06-12?',
#   'api_response': {'date': '2024-06-12',
#    'temperature': 22.18,
#    'description': 'scattered clouds',
#    'wind_speed': 1.84,
#    'humidity': 57},
#   'assistant_response': 'The forecast for Rome on 2024-06-12 is scattered clouds with a temperature of 22.18°C, wind speed of 1.84 meters per second, and humidity of 57%.'},
#  {'user_input': 'What is the current weather in Shanghai today?',
#   'api_response': {'location': 'Shanghai, CN',
#    'temperature': 21.76,
# ...
#   'api_response': {'location': 'Jakarta, ID',
#    'temperature': 29.85,
#    'description': 'scattered clouds',
#    'wind_speed': 3.6,
#    'humidity': 77},
#   'assistant_response': 'The weather in Jakarta is currently scattered clouds with a temperature of 29.85°C, wind speed of 3.6 meters per second, and humidity of 77%.'},
#  {'user_input': 'What is the current weather in Sendai today?',
#   'api_response': {'location': 'Sendai, JP',
#    'temperature': 16.64,
#    'description': 'scattered clouds',
#    'wind_speed': 1.44,
#    'humidity': 94},
#   'assistant_response': 'The weather in Sendai is currently scattered clouds with a temperature of 16.64°C, wind speed of 1.44 meters per second, and humidity of 94%.'},
#  {'user_input': 'What is the current weather in Tokyo today?',
#   'api_response': {'location': 'Tokyo, JP',
#    'temperature': 21.45,
#    'description': 'broken clouds',
#    'wind_speed': 2.57,
#    'humidity': 81},
#   'assistant_response': 'The weather in Tokyo is currently broken clouds with a temperature of 21.45°C, wind speed of 2.57 meters per second, and humidity of 81%.'},
#  {'user_input': 'What is the forecast weather in Osaka 2024-06-12?',
#   'api_response': {'date': '2024-06-12',
#    'temperature': 25.61,
#    'description': 'overcast clouds',
#    'wind_speed': 1.66,
#    'humidity': 64},
#   'assistant_response': 'The forecast for Osaka on 2024-06-12 is overcast clouds with a temperature of 25.61°C, wind speed of 1.66 meters per second, and humidity of 64%.'},
#  {'user_input': 'What is the current weather in Philadelphia today?',
#   'api_response': {'location': 'Philadelphia, US',
#    'temperature': 22.26,
#    'description': 'broken clouds',
#    'wind_speed': 5.14,
#    'humidity': 50},
#   'assistant_response': 'The weather in Philadelphia is currently broken clouds with a temperature of 22.26°C, wind speed of 5.14 meters per second, and humidity of 50%.'},
#  {'user_input': 'What is the forecast weather in Fukuoka 2024-06-14?',
#   'api_response': {'date': '2024-06-14',
#    'temperature': 26.34,
#    'description': 'scattered clouds',
#    'wind_speed': 1.28,
#    'humidity': 67},
#   'assistant_response': 'The forecast for Fukuoka on 2024-06-14 is scattered clouds with a temperature of 26.34°C, wind speed of 1.28 meters per second, and humidity of 67%.'},
#  {'user_input': 'What is the forecast weather in Milan 2024-06-14?',
#   'api_response': {'date': '2024-06-14',
#    'temperature': 13.35,
#    'description': 'clear sky',
#    'wind_speed': 1,
#    'humidity': 91},
#   'assistant_response': 'The forecast for Milan on 2024-06-14 is clear sky with a temperature of 13.35°C, wind speed of 1 meters per second, and humidity of 91%.'},
#  {'user_input': 'What is the current weather in Toulouse today?',
#   'api_response': {'location': 'Toulouse, FR',
#    'temperature': 22.99,
#    'description': 'clear sky',
#    'wind_speed': 7.2,
#    'humidity': 46},
#   'assistant_response': 'The weather in Toulouse is currently clear sky with a temperature of 22.99°C, wind speed of 7.2 meters per second, and humidity of 46%.'},
#  {'user_input': 'What is the current weather in Los Angeles today?',
#   'api_response': {'location': 'Los Angeles, US',
#    'temperature': 16.65,
#    'description': 'haze',
#    'wind_speed': 2.06,
#    'humidity': 83},
#   'assistant_response': 'The weather in Los Angeles is currently haze with a temperature of 16.65°C, wind speed of 2.06 meters per second, and humidity of 83%.'},
#  {'user_input': 'What is the forecast weather in Oslo 2024-06-12?',
#   'api_response': {'date': '2024-06-12',
#    'temperature': 10.06,
#    'description': 'light rain',
#    'wind_speed': 0.8,
#    'humidity': 96},
#   'assistant_response': 'The forecast for Oslo on 2024-06-12 is light rain with a temperature of 10.06°C, wind speed of 0.8 meters per second, and humidity of 96%.'},
#  {'user_input': 'What is the forecast weather in Nice 2024-06-12?',
#   'api_response': {'date': '2024-06-12',
#    'temperature': 9.18,
#    'description': 'overcast clouds',
#    'wind_speed': 2.16,
#    'humidity': 89},
#   'assistant_response': 'The forecast for Nice on 2024-06-12 is overcast clouds with a temperature of 9.18°C, wind speed of 2.16 meters per second, and humidity of 89%.'},
#  {'user_input': 'What is the forecast weather in Dhaka 2024-06-12?',
#   'api_response': {'date': '2024-06-12',
#    'temperature': 28.65,
#    'description': 'overcast clouds',
#    'wind_speed': 4.32,
#    'humidity': 83},
#   'assistant_response': 'The forecast for Dhaka on 2024-06-12 is overcast clouds with a temperature of 28.65°C, wind speed of 4.32 meters per second, and humidity of 83%.'},
#  {'user_input': 'What is the current weather in Kyoto today?',
#   'api_response': {'location': 'Kyoto, JP',
#    'temperature': 22.14,
#    'description': 'broken clouds',
#    'wind_speed': 0.83,
#    'humidity': 79},
#   'assistant_response': 'The weather in Kyoto is currently broken clouds with a temperature of 22.14°C, wind speed of 0.83 meters per second, and humidity of 79%.'},
#  {'user_input': 'What is the current weather in Athens today?',
#   'api_response': {'location': 'Athens, GR',
#    'temperature': 32.49,
#    'description': 'clear sky',
#    'wind_speed': 5.14,
#    'humidity': 42},
#   'assistant_response': 'The weather in Athens is currently clear sky with a temperature of 32.49°C, wind speed of 5.14 meters per second, and humidity of 42%.'},
#  {'user_input': 'What is the current weather in Zurich today?',
#   'api_response': {'location': 'Zurich, CH',
#    'temperature': 21.27,
#    'description': 'few clouds',
#    'wind_speed': 3.6,
#    'humidity': 51},
#   'assistant_response': 'The weather in Zurich is currently few clouds with a temperature of 21.27°C, wind speed of 3.6 meters per second, and humidity of 51%.'},
#  {'user_input': 'What is the current weather in New York today?',
#   'api_response': {'location': 'New York, US',
#    'temperature': 21.05,
#    'description': 'broken clouds',
#    'wind_speed': 6.71,
#    'humidity': 50},
#   'assistant_response': 'The weather in New York is currently broken clouds with a temperature of 21.05°C, wind speed of 6.71 meters per second, and humidity of 50%.'},
#  {'user_input': 'What is the forecast weather in Paris 2024-06-11?',
#   'api_response': {'date': '2024-06-11',
#    'temperature': 9.52,
#    'description': 'scattered clouds',
#    'wind_speed': 1.52,
#    'humidity': 84},
#   'assistant_response': 'The forecast for Paris on 2024-06-11 is scattered clouds with a temperature of 9.52°C, wind speed of 1.52 meters per second, and humidity of 84%.'},
#  {'user_input': 'What is the current weather in Hiroshima today?',
#   'api_response': {'location': 'Hiroshima, JP',
#    'temperature': 21.02,
#    'description': 'scattered clouds',
#    'wind_speed': 0.99,
#    'humidity': 96},
#   'assistant_response': 'The weather in Hiroshima is currently scattered clouds with a temperature of 21.02°C, wind speed of 0.99 meters per second, and humidity of 96%.'},
#  {'user_input': 'What is the forecast weather in Hanoi 2024-06-12?',
#   'api_response': {'date': '2024-06-12',
#    'temperature': 28.22,
#    'description': 'overcast clouds',
#    'wind_speed': 1.15,
#    'humidity': 86},
#   'assistant_response': 'The forecast for Hanoi on 2024-06-12 is overcast clouds with a temperature of 28.22°C, wind speed of 1.15 meters per second, and humidity of 86%.'},
#  {'user_input': 'What is the forecast weather in Tokyo 2024-06-14?',
#   'api_response': {'date': '2024-06-14',
#    'temperature': 26.51,
#    'description': 'clear sky',
#    'wind_speed': 2.35,
#    'humidity': 55},
#   'assistant_response': 'The forecast for Tokyo on 2024-06-14 is clear sky with a temperature of 26.51°C, wind speed of 2.35 meters per second, and humidity of 55%.'},
#  {'user_input': 'What is the forecast weather in Abu Dhabi 2024-06-12?',
#   'api_response': {'date': '2024-06-12',
#    'temperature': 32.47,
#    'description': 'clear sky',
#    'wind_speed': 1.69,
#    'humidity': 59},
#   'assistant_response': 'The forecast for Abu Dhabi on 2024-06-12 is clear sky with a temperature of 32.47°C, wind speed of 1.69 meters per second, and humidity of 59%.'},
#  {'user_input': 'What is the forecast weather in Madrid 2024-06-13?',
#   'api_response': {'date': '2024-06-13',
#    'temperature': 17.52,
#    'description': 'broken clouds',
#    'wind_speed': 4.41,
#    'humidity': 54},
#   'assistant_response': 'The forecast for Madrid on 2024-06-13 is broken clouds with a temperature of 17.52°C, wind speed of 4.41 meters per second, and humidity of 54%.'},
#  {'user_input': 'What is the forecast weather in Bordeaux 2024-06-15?',
#   'api_response': {'date': '2024-06-15',
#    'temperature': 15.81,
#    'description': 'overcast clouds',
#    'wind_speed': 2.78,
#    'humidity': 82},
#   'assistant_response': 'The forecast for Bordeaux on 2024-06-15 is overcast clouds with a temperature of 15.81°C, wind speed of 2.78 meters per second, and humidity of 82%.'},
#  {'user_input': 'What is the forecast weather in Mexico City 2024-06-14?',
#   'api_response': {'date': '2024-06-14',
#    'temperature': 25.2,
#    'description': 'overcast clouds',
#    'wind_speed': 7.69,
#    'humidity': 30},
#   'assistant_response': 'The forecast for Mexico City on 2024-06-14 is overcast clouds with a temperature of 25.2°C, wind speed of 7.69 meters per second, and humidity of 30%.'},
#  {'user_input': 'What is the current weather in Chicago today?',
#   'api_response': {'location': 'Chicago, US',
#    'temperature': 15.5,
#    'description': 'broken clouds',
#    'wind_speed': 6.17,
#    'humidity': 61},
#   'assistant_response': 'The weather in Chicago is currently broken clouds with a temperature of 15.5°C, wind speed of 6.17 meters per second, and humidity of 61%.'},
#  {'user_input': 'What is the forecast weather in Kobe 2024-06-12?',
#   'api_response': {'date': '2024-06-12',
#    'temperature': 24.18,
#    'description': 'overcast clouds',
#    'wind_speed': 0.76,
#    'humidity': 73},
#   'assistant_response': 'The forecast for Kobe on 2024-06-12 is overcast clouds with a temperature of 24.18°C, wind speed of 0.76 meters per second, and humidity of 73%.'},
#  {'user_input': 'What is the current weather in Cairo today?',
#   'api_response': {'location': 'Cairo, EG',
#    'temperature': 36.42,
#    'description': 'clear sky',
#    'wind_speed': 3.6,
#    'humidity': 26},
#   'assistant_response': 'The weather in Cairo is currently clear sky with a temperature of 36.42°C, wind speed of 3.6 meters per second, and humidity of 26%.'},
#  {'user_input': 'What is the forecast weather in Naples 2024-06-15?',
#   'api_response': {'date': '2024-06-15',
#    'temperature': 21.39,
#    'description': 'clear sky',
#    'wind_speed': 2.07,
#    'humidity': 70},
#   'assistant_response': 'The forecast for Naples on 2024-06-15 is clear sky with a temperature of 21.39°C, wind speed of 2.07 meters per second, and humidity of 70%.'},
#  {'user_input': 'What is the forecast weather in Dallas 2024-06-15?',
#   'api_response': {'date': '2024-06-15',
#    'temperature': 31.38,
#    'description': 'clear sky',
#    'wind_speed': 4.1,
#    'humidity': 42},
#   'assistant_response': 'The forecast for Dallas on 2024-06-15 is clear sky with a temperature of 31.38°C, wind speed of 4.1 meters per second, and humidity of 42%.'},
#  {'user_input': 'What is the forecast weather in Dublin 2024-06-14?',
#   'api_response': {'date': '2024-06-14',
#    'temperature': 23.44,
#    'description': 'clear sky',
#    'wind_speed': 4.71,
#    'humidity': 35},
#   'assistant_response': 'The forecast for Dublin on 2024-06-14 is clear sky with a temperature of 23.44°C, wind speed of 4.71 meters per second, and humidity of 35%.'},
#  {'user_input': 'What is the forecast weather in Edinburgh 2024-06-11?',
#   'api_response': {'date': '2024-06-11',
#    'temperature': 7.17,
#    'description': 'overcast clouds',
#    'wind_speed': 3,
#    'humidity': 76},
#   'assistant_response': 'The forecast for Edinburgh on 2024-06-11 is overcast clouds with a temperature of 7.17°C, wind speed of 3 meters per second, and humidity of 76%.'},
#  {'user_input': 'What is the forecast weather in Hiroshima 2024-06-14?',
#   'api_response': {'date': '2024-06-14',
#    'temperature': 25.6,
#    'description': 'clear sky',
#    'wind_speed': 0.85,
#    'humidity': 64},
#   'assistant_response': 'The forecast for Hiroshima on 2024-06-14 is clear sky with a temperature of 25.6°C, wind speed of 0.85 meters per second, and humidity of 64%.'},
#  {'user_input': 'What is the current weather in São Paulo today?',
#   'api_response': {'location': 'São Paulo, BR',
#    'temperature': 25.29,
#    'description': 'clear sky',
#    'wind_speed': 4.63,
#    'humidity': 60},
#   'assistant_response': 'The weather in São Paulo is currently clear sky with a temperature of 25.29°C, wind speed of 4.63 meters per second, and humidity of 60%.'},
#  {'user_input': 'What is the current weather in Dublin today?',
#   'api_response': {'location': 'Dublin, US',
#    'temperature': 14.29,
#    'description': 'few clouds',
#    'wind_speed': 2.06,
#    'humidity': 82},
#   'assistant_response': 'The weather in Dublin is currently few clouds with a temperature of 14.29°C, wind speed of 2.06 meters per second, and humidity of 82%.'},
#  {'user_input': 'What is the forecast weather in Kobe 2024-06-15?',
#   'api_response': {'date': '2024-06-15',
#    'temperature': 24.54,
#    'description': 'overcast clouds',
#    'wind_speed': 3.39,
#    'humidity': 65},
#   'assistant_response': 'The forecast for Kobe on 2024-06-15 is overcast clouds with a temperature of 24.54°C, wind speed of 3.39 meters per second, and humidity of 65%.'},
#  {'user_input': 'What is the forecast weather in Amsterdam 2024-06-11?',
#   'api_response': {'date': '2024-06-11',
#    'temperature': 8.61,
#    'description': 'light rain',
#    'wind_speed': 4.29,
#    'humidity': 86},
#   'assistant_response': 'The forecast for Amsterdam on 2024-06-11 is light rain with a temperature of 8.61°C, wind speed of 4.29 meters per second, and humidity of 86%.'},
#  {'user_input': 'What is the forecast weather in Dubai 2024-06-15?',
#   'api_response': {'date': '2024-06-15',
#    'temperature': 31.52,
#    'description': 'clear sky',
#    'wind_speed': 3.78,
#    'humidity': 60},
#   'assistant_response': 'The forecast for Dubai on 2024-06-15 is clear sky with a temperature of 31.52°C, wind speed of 3.78 meters per second, and humidity of 60%.'},
#  {'user_input': 'What is the current weather in Austin today?',
#   'api_response': {'location': 'Austin, US',
#    'temperature': 27.33,
#    'description': 'broken clouds',
#    'wind_speed': 2.57,
#    'humidity': 82},
#   'assistant_response': 'The weather in Austin is currently broken clouds with a temperature of 27.33°C, wind speed of 2.57 meters per second, and humidity of 82%.'},
#  {'user_input': 'What is the forecast weather in Tehran 2024-06-12?',
#   'api_response': {'date': '2024-06-12',
#    'temperature': 27.1,
#    'description': 'broken clouds',
#    'wind_speed': 3.35,
#    'humidity': 26},
#   'assistant_response': 'The forecast for Tehran on 2024-06-12 is broken clouds with a temperature of 27.1°C, wind speed of 3.35 meters per second, and humidity of 26%.'},
#  {'user_input': 'What is the current weather in Istanbul today?',
#   'api_response': {'location': 'Istanbul, TR',
#    'temperature': 26.68,
#    'description': 'clear sky',
#    'wind_speed': 3.09,
#    'humidity': 58},
#   'assistant_response': 'The weather in Istanbul is currently clear sky with a temperature of 26.68°C, wind speed of 3.09 meters per second, and humidity of 58%.'},
#  {'user_input': 'What is the current weather in Athens today?',
#   'api_response': {'location': 'Athens, GR',
#    'temperature': 32.46,
#    'description': 'clear sky',
#    'wind_speed': 5.14,
#    'humidity': 42},
#   'assistant_response': 'The weather in Athens is currently clear sky with a temperature of 32.46°C, wind speed of 5.14 meters per second, and humidity of 42%.'},
#  {'user_input': 'What is the forecast weather in Oslo 2024-06-11?',
#   'api_response': {'date': '2024-06-11',
#    'temperature': 7.66,
#    'description': 'broken clouds',
#    'wind_speed': 1.13,
#    'humidity': 86},
#   'assistant_response': 'The forecast for Oslo on 2024-06-11 is broken clouds with a temperature of 7.66°C, wind speed of 1.13 meters per second, and humidity of 86%.'}]

# %%
combined_data = []
for intent, response in zip(intent_dataset, response_dataset):
    combined_entry = {
        "user_input": intent["user_input"],
        "intent_extraction": intent["intent_extraction"],
        "api_response": response["api_response"],
        "assistant_response": response["assistant_response"]
    }
    combined_data.append(combined_entry)

# %%
# combined_data

# %%
with open('data/weather_chatbot_dataset.json', 'w') as f:
    json.dump(combined_data, f, indent=4)

# %%
# weather_chatbot_data

# %%
# !ssh -T git@hf.co
# Out:
# Hi VatsalPatel18, welcome to Hugging Face.

# %%
from huggingface_hub import login

login(token='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')
# login(token="YOUR_HUGGING_FACE_TOKEN")
# Load the dataset from the JSON file
from datasets import load_dataset

dataset = load_dataset('json', data_files='data/weather_chatbot_dataset.json')

# Push the dataset to Hugging Face Hub
dataset.push_to_hub("VatsalPatel18/Open-Weather-ChatBot")
# Out:
# The token has not been saved to the git credentials helper. Pass `add_to_git_credential=True` in this function directly or `--add-to-git-credential` if using via `huggingface-cli` if you want to set the git credential as well.
# Token is valid (permission: write).
# Your token has been saved to /home/vatsal-patel/.cache/huggingface/token
# Login successful
# Generating train split: 0 examples [00:00, ? examples/s]
# Uploading the dataset shards:   0%|          | 0/1 [00:00<?, ?it/s]
# Creating parquet from Arrow format:   0%|          | 0/1 [00:00<?, ?ba/s]
# README.md:   0%|          | 0.00/36.0 [00:00<?, ?B/s]
# CommitInfo(commit_url='https://huggingface.co/datasets/VatsalPatel18/Open-Weather-ChatBot/commit/c537f6bf1494281e0b653b4bb4d2dd0623855611', commit_message='Upload dataset', commit_description='', oid='c537f6bf1494281e0b653b4bb4d2dd0623855611', pr_url=None, pr_revision=None, pr_num=None)

# %%
# hugging_face_token
